# %%
# !pip install -Uqq sagemaker

# %%
import requests
from io import BytesIO
import pandas as pd
import boto3
import s3fs
from datetime import datetime
import time
import sagemaker
from sagemaker.estimator import Estimator
from sagemaker import image_uris
from sagemaker.inputs import TrainingInput
from sagemaker.debugger import Rule, rule_configs

from IPython.core.display import display, HTML

# %%
# setup sagemaker variables
role = sagemaker.get_execution_role()
sess = sagemaker.session.Session()
bucket = sess.default_bucket()
key_prefix = "higgs-boson"
region = sess._region_name
s3 = s3fs.S3FileSystem(anon=False)

xgboost_container = image_uris.retrieve("xgboost", region, "1.2-1")

# %%
xgboost_container
# Out:
# '683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-xgboost:1.2-1'

# %%
# get data from CERN
data_url = "http://opendata.cern.ch/record/328/files/atlas-higgs-challenge-2014-v2.csv.gz"
gz_file = BytesIO(requests.get(data_url).content)
gz_file.flush()
df = pd.read_csv(gz_file, compression="gzip")

# %%
# identify feature, label, and unused columns
non_feature_cols = ["EventId", "Weight", "KaggleSet", "KaggleWeight", "Label"]
feature_cols = [col for col in df.columns if col not in non_feature_cols]
label_col = "Label"
df["Label"] = df["Label"].apply(lambda x: 1 if x=="s" else 0)

# take subsets of data per the original Kaggle competition
train_data = df.loc[df["KaggleSet"] == "t", [label_col, *feature_cols]]
test_data = df.loc[df["KaggleSet"] == "b", [label_col, *feature_cols]]

# %%
# upload data to S3
for name, dataset in zip(["train", "test"], [train_data, test_data]):
    sess.upload_string_as_file_body(body=dataset.to_csv(index=False, header=False),
                                   bucket=bucket,
                                   key=f"{key_prefix}/input/{name}.csv"
                                   )

# %%
# configure data inputs for SageMaker training
train_input = TrainingInput(f"s3://{bucket}/{key_prefix}/input/train.csv", content_type="text/csv")
validation_input = TrainingInput(f"s3://{bucket}/{key_prefix}/input/test.csv", content_type="text/csv")

# %%
# add a rule to generate the XGBoost Report
rules=[
    Rule.sagemaker(rule_configs.create_xgboost_report())
]

# %%
# baseline hyperparams
# hyperparameters={
#     "objective": "binary:logistic",
#     "num_round": "100",
#     "eval_metric": "error"
# }

hyperparameters={
    "eta": "0.1",
    "max_depth": "6",
    "objective": "binary:logistic",
    "scale_pos_weight": "595",
    "num_round": "3000"
}

# %%
estimator=Estimator(
    role=role,
    image_uri=xgboost_container,
    base_job_name="higgs-boson-model",
    instance_count=1,
    instance_type="ml.m5.2xlarge",
    hyperparameters=hyperparameters,
    rules=rules, 
)

training_job_time = datetime.now()
estimator.fit({'train': train_input, 'validation': validation_input}, 
              wait=True)
# Out:
# 2021-01-11 16:34:57 Starting - Starting the training job...
# 2021-01-11 16:35:23 Starting - Launching requested ML instancesCreateXgboostReport: InProgress
# ProfilerReport-1610382897: InProgress
# ......
# 2021-01-11 16:36:24 Starting - Preparing the instances for training......
# 2021-01-11 16:37:25 Downloading - Downloading input data
# 2021-01-11 16:37:25 Training - Downloading the training image...
# 2021-01-11 16:37:54 Training - Training image download completed. Training in progress.INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Single node training.
# [2021-01-11 16:37:44.425 ip-10-0-165-9.ec2.internal:1 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2021-01-11 16:37:44.426 ip-10-0-165-9.ec2.internal:1 INFO hook.py:192] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2021-01-11 16:37:44.426 ip-10-0-165-9.ec2.internal:1 INFO hook.py:237] Saving to /opt/ml/output/tensors
# [2021-01-11 16:37:44.426 ip-10-0-165-9.ec2.internal:1 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 250000 rows
# INFO:root:Validation matrix has 100000 rows
# [0]#011train-error:0.63054#011validation-error:0.63484
# [2021-01-11 16:37:44.760 ip-10-0-165-9.ec2.internal:1 INFO hook.py:382] Monitoring the collections: labels, predictions, metrics, feature_importance, hyperparameters
# [2021-01-11 16:37:44.770 ip-10-0-165-9.ec2.internal:1 INFO hook.py:443] Hook is writing from the hook with pid: 1
#
# [1]#011train-error:0.62433#011validation-error:0.62858
# [2]#011train-error:0.63468#011validation-error:0.63879
# [3]#011train-error:0.63056#011validation-error:0.63467
# [4]#011train-error:0.63112#011validation-error:0.63510
# [5]#011train-error:0.63156#011validation-error:0.63527
# [6]#011train-error:0.63004#011validation-error:0.63373
# [7]#011train-error:0.63124#011validation-error:0.63448
# [8]#011train-error:0.62987#011validation-error:0.63329
# [9]#011train-error:0.62912#011validation-error:0.63279
# [10]#011train-error:0.62944#011validation-error:0.63281
# [11]#011train-error:0.62897#011validation-error:0.63239
# [12]#011train-error:0.62760#011validation-error:0.63115
# [13]#011train-error:0.62723#011validation-error:0.63074
# [14]#011train-error:0.62736#011validation-error:0.63095
# [15]#011train-error:0.62675#011validation-error:0.63031
# [16]#011train-error:0.62634#011validation-error:0.62971
# [17]#011train-error:0.62602#011validation-error:0.62952
# [18]#011train-error:0.62608#011validation-error:0.62964
# [19]#011train-error:0.62626#011validation-error:0.62991
# [20]#011train-error:0.62599#011validation-error:0.62955
# [21]#011train-error:0.62605#011validation-error:0.62955
# [22]#011train-error:0.62614#011validation-error:0.62957
# [23]#011train-error:0.62553#011validation-error:0.62892
# [24]#011train-error:0.62512#011validation-error:0.62873
# [25]#011train-error:0.62510#011validation-error:0.62851
# [26]#011train-error:0.62430#011validation-error:0.62763
# [27]#011train-error:0.62376#011validation-error:0.62707
# [28]#011train-error:0.62346#011validation-error:0.62655
# [29]#011train-error:0.62295#011validation-error:0.62622
# [30]#011train-error:0.62226#011validation-error:0.62562
# [31]#011train-error:0.62181#011validation-error:0.62510
# [32]#011train-error:0.62130#011validation-error:0.62450
# [33]#011train-error:0.62079#011validation-error:0.62394
# [34]#011train-error:0.62006#011validation-error:0.62339
# [35]#011train-error:0.61930#011validation-error:0.62298
# [36]#011train-error:0.61875#011validation-error:0.62248
# [37]#011train-error:0.61802#011validation-error:0.62146
# [38]#011train-error:0.61758#011validation-error:0.62091
# [39]#011train-error:0.61707#011validation-error:0.62031
# [40]#011train-error:0.61638#011validation-error:0.61989
# [41]#011train-error:0.61587#011validation-error:0.61933
# [42]#011train-error:0.61526#011validation-error:0.61888
# [43]#011train-error:0.61490#011validation-error:0.61842
# [44]#011train-error:0.61425#011validation-error:0.61775
# [45]#011train-error:0.61367#011validation-error:0.61730
# [46]#011train-error:0.61317#011validation-error:0.61698
# [47]#011train-error:0.61222#011validation-error:0.61622
# [48]#011train-error:0.61160#011validation-error:0.61560
# [49]#011train-error:0.61088#011validation-error:0.61495
# [50]#011train-error:0.61063#011validation-error:0.61469
# [51]#011train-error:0.60984#011validation-error:0.61364
# [52]#011train-error:0.60941#011validation-error:0.61309
# [53]#011train-error:0.60881#011validation-error:0.61258
# [54]#011train-error:0.60831#011validation-error:0.61222
# [55]#011train-error:0.60773#011validation-error:0.61160
# [56]#011train-error:0.60750#011validation-error:0.61128
# [57]#011train-error:0.60712#011validation-error:0.61093
# [58]#011train-error:0.60674#011validation-error:0.61046
# [59]#011train-error:0.60594#011validation-error:0.60987
# [60]#011train-error:0.60541#011validation-error:0.60945
# [61]#011train-error:0.60487#011validation-error:0.60890
# [62]#011train-error:0.60445#011validation-error:0.60843
# [63]#011train-error:0.60404#011validation-error:0.60792
# [64]#011train-error:0.60348#011validation-error:0.60724
# [65]#011train-error:0.60296#011validation-error:0.60680
# [66]#011train-error:0.60262#011validation-error:0.60660
# [67]#011train-error:0.60173#011validation-error:0.60566
# [68]#011train-error:0.60134#011validation-error:0.60536
# [69]#011train-error:0.60065#011validation-error:0.60478
# [70]#011train-error:0.60000#011validation-error:0.60409
# [71]#011train-error:0.59937#011validation-error:0.60366
# [72]#011train-error:0.59863#011validation-error:0.60300
# [73]#011train-error:0.59798#011validation-error:0.60243
# [74]#011train-error:0.59729#011validation-error:0.60176
# [75]#011train-error:0.59665#011validation-error:0.60122
# [76]#011train-error:0.59621#011validation-error:0.60079
# [77]#011train-error:0.59557#011validation-error:0.60015
# [78]#011train-error:0.59480#011validation-error:0.59938
# [79]#011train-error:0.59434#011validation-error:0.59902
# [80]#011train-error:0.59356#011validation-error:0.59821
# [81]#011train-error:0.59296#011validation-error:0.59746
# [82]#011train-error:0.59249#011validation-error:0.59701
# [83]#011train-error:0.59175#011validation-error:0.59635
# [84]#011train-error:0.59139#011validation-error:0.59592
# [85]#011train-error:0.59063#011validation-error:0.59516
# [86]#011train-error:0.58995#011validation-error:0.59478
# [87]#011train-error:0.58928#011validation-error:0.59426
# [88]#011train-error:0.58868#011validation-error:0.59374
# [89]#011train-error:0.58783#011validation-error:0.59307
# [90]#011train-error:0.58703#011validation-error:0.59208
# [91]#011train-error:0.58659#011validation-error:0.59171
# [92]#011train-error:0.58623#011validation-error:0.59121
# [93]#011train-error:0.58552#011validation-error:0.59035
# [94]#011train-error:0.58477#011validation-error:0.58983
# [95]#011train-error:0.58401#011validation-error:0.58934
# [96]#011train-error:0.58308#011validation-error:0.58835
# [97]#011train-error:0.58284#011validation-error:0.58815
# [98]#011train-error:0.58242#011validation-error:0.58773
# [99]#011train-error:0.58206#011validation-error:0.58736
# [100]#011train-error:0.58178#011validation-error:0.58714
# [101]#011train-error:0.58132#011validation-error:0.58665
# [102]#011train-error:0.58077#011validation-error:0.58631
# [103]#011train-error:0.58051#011validation-error:0.58602
# [104]#011train-error:0.58001#011validation-error:0.58552
# [105]#011train-error:0.57972#011validation-error:0.58520
# [106]#011train-error:0.57888#011validation-error:0.58448
# [107]#011train-error:0.57829#011validation-error:0.58393
# [108]#011train-error:0.57801#011validation-error:0.58358
# [109]#011train-error:0.57782#011validation-error:0.58337
# [110]#011train-error:0.57680#011validation-error:0.58252
# [111]#011train-error:0.57656#011validation-error:0.58214
# [112]#011train-error:0.57588#011validation-error:0.58176
# [113]#011train-error:0.57554#011validation-error:0.58143
# [114]#011train-error:0.57442#011validation-error:0.58035
# [115]#011train-error:0.57390#011validation-error:0.57988
# [116]#011train-error:0.57363#011validation-error:0.57951
# [117]#011train-error:0.57270#011validation-error:0.57878
# [118]#011train-error:0.57266#011validation-error:0.57864
# [119]#011train-error:0.57220#011validation-error:0.57834
# [120]#011train-error:0.57150#011validation-error:0.57770
# [121]#011train-error:0.57086#011validation-error:0.57724
# [122]#011train-error:0.57047#011validation-error:0.57683
# [123]#011train-error:0.56992#011validation-error:0.57634
# [124]#011train-error:0.56976#011validation-error:0.57629
# [125]#011train-error:0.56962#011validation-error:0.57622
# [126]#011train-error:0.56925#011validation-error:0.57586
# [127]#011train-error:0.56911#011validation-error:0.57565
# [128]#011train-error:0.56888#011validation-error:0.57546
# [129]#011train-error:0.56849#011validation-error:0.57519
# [130]#011train-error:0.56790#011validation-error:0.57472
# [131]#011train-error:0.56774#011validation-error:0.57448
# [132]#011train-error:0.56714#011validation-error:0.57406
# [133]#011train-error:0.56652#011validation-error:0.57338
# [134]#011train-error:0.56622#011validation-error:0.57305
# [135]#011train-error:0.56613#011validation-error:0.57303
# [136]#011train-error:0.56576#011validation-error:0.57270
# [137]#011train-error:0.56519#011validation-error:0.57237
# [138]#011train-error:0.56501#011validation-error:0.57222
# [139]#011train-error:0.56486#011validation-error:0.57207
# [140]#011train-error:0.56417#011validation-error:0.57143
# [141]#011train-error:0.56339#011validation-error:0.57063
# [142]#011train-error:0.56247#011validation-error:0.56973
# [143]#011train-error:0.56210#011validation-error:0.56934
# [144]#011train-error:0.56194#011validation-error:0.56919
# [145]#011train-error:0.56186#011validation-error:0.56905
# [146]#011train-error:0.56146#011validation-error:0.56872
# [147]#011train-error:0.56061#011validation-error:0.56821
# [148]#011train-error:0.56022#011validation-error:0.56795
# [149]#011train-error:0.55937#011validation-error:0.56735
# [150]#011train-error:0.55910#011validation-error:0.56708
# [151]#011train-error:0.55875#011validation-error:0.56678
# [152]#011train-error:0.55842#011validation-error:0.56666
# [153]#011train-error:0.55799#011validation-error:0.56633
# [154]#011train-error:0.55753#011validation-error:0.56575
# [155]#011train-error:0.55745#011validation-error:0.56565
# [156]#011train-error:0.55724#011validation-error:0.56541
# [157]#011train-error:0.55679#011validation-error:0.56481
# [158]#011train-error:0.55656#011validation-error:0.56468
# [159]#011train-error:0.55652#011validation-error:0.56461
# [160]#011train-error:0.55637#011validation-error:0.56446
# [161]#011train-error:0.55636#011validation-error:0.56442
# [162]#011train-error:0.55602#011validation-error:0.56420
# [163]#011train-error:0.55556#011validation-error:0.56381
# [164]#011train-error:0.55476#011validation-error:0.56301
# [165]#011train-error:0.55431#011validation-error:0.56276
# [166]#011train-error:0.55363#011validation-error:0.56224
# [167]#011train-error:0.55314#011validation-error:0.56186
# [168]#011train-error:0.55301#011validation-error:0.56169
# [169]#011train-error:0.55272#011validation-error:0.56143
# [170]#011train-error:0.55230#011validation-error:0.56105
# [171]#011train-error:0.55214#011validation-error:0.56091
# [172]#011train-error:0.55174#011validation-error:0.56054
# [173]#011train-error:0.55142#011validation-error:0.56026
# [174]#011train-error:0.55133#011validation-error:0.56017
# [175]#011train-error:0.55064#011validation-error:0.55956
# [176]#011train-error:0.55050#011validation-error:0.55934
# [177]#011train-error:0.55006#011validation-error:0.55895
# [178]#011train-error:0.54989#011validation-error:0.55887
# [179]#011train-error:0.54978#011validation-error:0.55878
# [180]#011train-error:0.54960#011validation-error:0.55864
# [181]#011train-error:0.54880#011validation-error:0.55787
# [182]#011train-error:0.54779#011validation-error:0.55682
# [183]#011train-error:0.54750#011validation-error:0.55657
# [184]#011train-error:0.54742#011validation-error:0.55651
# [185]#011train-error:0.54697#011validation-error:0.55631
# [186]#011train-error:0.54689#011validation-error:0.55626
# [187]#011train-error:0.54680#011validation-error:0.55609
# [188]#011train-error:0.54627#011validation-error:0.55560
# [189]#011train-error:0.54620#011validation-error:0.55554
# [190]#011train-error:0.54600#011validation-error:0.55534
# [191]#011train-error:0.54542#011validation-error:0.55487
# [192]#011train-error:0.54494#011validation-error:0.55462
# [193]#011train-error:0.54477#011validation-error:0.55442
# [194]#011train-error:0.54466#011validation-error:0.55423
# [195]#011train-error:0.54451#011validation-error:0.55411
# [196]#011train-error:0.54431#011validation-error:0.55383
# [197]#011train-error:0.54390#011validation-error:0.55349
# [198]#011train-error:0.54376#011validation-error:0.55333
# [199]#011train-error:0.54338#011validation-error:0.55291
# [200]#011train-error:0.54295#011validation-error:0.55254
# [201]#011train-error:0.54271#011validation-error:0.55220
# [202]#011train-error:0.54237#011validation-error:0.55183
# [203]#011train-error:0.54189#011validation-error:0.55131
# [204]#011train-error:0.54178#011validation-error:0.55126
# [205]#011train-error:0.54146#011validation-error:0.55090
# [206]#011train-error:0.54116#011validation-error:0.55064
# [207]#011train-error:0.54094#011validation-error:0.55042
# [208]#011train-error:0.54090#011validation-error:0.55037
# [209]#011train-error:0.54033#011validation-error:0.54985
# [210]#011train-error:0.53974#011validation-error:0.54947
# [211]#011train-error:0.53942#011validation-error:0.54908
# [212]#011train-error:0.53899#011validation-error:0.54872
# [213]#011train-error:0.53875#011validation-error:0.54845
# [214]#011train-error:0.53844#011validation-error:0.54806
# [215]#011train-error:0.53819#011validation-error:0.54785
# [216]#011train-error:0.53765#011validation-error:0.54753
# [217]#011train-error:0.53737#011validation-error:0.54727
# [218]#011train-error:0.53717#011validation-error:0.54708
# [219]#011train-error:0.53652#011validation-error:0.54656
# [220]#011train-error:0.53646#011validation-error:0.54648
# [221]#011train-error:0.53614#011validation-error:0.54624
# [222]#011train-error:0.53582#011validation-error:0.54603
# [223]#011train-error:0.53552#011validation-error:0.54583
# [224]#011train-error:0.53544#011validation-error:0.54583
# [225]#011train-error:0.53535#011validation-error:0.54579
# [226]#011train-error:0.53520#011validation-error:0.54563
# [227]#011train-error:0.53510#011validation-error:0.54550
# [228]#011train-error:0.53480#011validation-error:0.54513
# [229]#011train-error:0.53440#011validation-error:0.54493
# [230]#011train-error:0.53429#011validation-error:0.54480
# [231]#011train-error:0.53409#011validation-error:0.54460
# [232]#011train-error:0.53365#011validation-error:0.54406
# [233]#011train-error:0.53324#011validation-error:0.54376
# [234]#011train-error:0.53260#011validation-error:0.54325
# [235]#011train-error:0.53254#011validation-error:0.54319
# [236]#011train-error:0.53237#011validation-error:0.54295
# [237]#011train-error:0.53216#011validation-error:0.54293
# [238]#011train-error:0.53210#011validation-error:0.54279
# [239]#011train-error:0.53180#011validation-error:0.54249
# [240]#011train-error:0.53166#011validation-error:0.54239
# [241]#011train-error:0.53146#011validation-error:0.54230
# [242]#011train-error:0.53100#011validation-error:0.54189
# [243]#011train-error:0.53082#011validation-error:0.54188
# [244]#011train-error:0.53079#011validation-error:0.54179
# [245]#011train-error:0.53064#011validation-error:0.54179
# [246]#011train-error:0.53010#011validation-error:0.54131
# [247]#011train-error:0.53000#011validation-error:0.54122
# [248]#011train-error:0.52978#011validation-error:0.54107
# [249]#011train-error:0.52917#011validation-error:0.54051
# [250]#011train-error:0.52884#011validation-error:0.54033
# [251]#011train-error:0.52876#011validation-error:0.54024
# [252]#011train-error:0.52855#011validation-error:0.53999
# [253]#011train-error:0.52837#011validation-error:0.53991
# [254]#011train-error:0.52809#011validation-error:0.53954
# [255]#011train-error:0.52793#011validation-error:0.53936
# [256]#011train-error:0.52779#011validation-error:0.53927
# [257]#011train-error:0.52768#011validation-error:0.53918
# [258]#011train-error:0.52742#011validation-error:0.53887
# [259]#011train-error:0.52712#011validation-error:0.53870
# [260]#011train-error:0.52675#011validation-error:0.53860
# [261]#011train-error:0.52640#011validation-error:0.53832
# [262]#011train-error:0.52633#011validation-error:0.53827
# [263]#011train-error:0.52578#011validation-error:0.53776
# [264]#011train-error:0.52529#011validation-error:0.53719
# [265]#011train-error:0.52513#011validation-error:0.53699
# [266]#011train-error:0.52497#011validation-error:0.53691
# [267]#011train-error:0.52469#011validation-error:0.53670
# [268]#011train-error:0.52455#011validation-error:0.53649
# [269]#011train-error:0.52437#011validation-error:0.53620
# [270]#011train-error:0.52383#011validation-error:0.53566
# [271]#011train-error:0.52374#011validation-error:0.53554
# [272]#011train-error:0.52355#011validation-error:0.53536
# [273]#011train-error:0.52337#011validation-error:0.53516
# [274]#011train-error:0.52326#011validation-error:0.53513
# [275]#011train-error:0.52317#011validation-error:0.53505
# [276]#011train-error:0.52312#011validation-error:0.53509
# [277]#011train-error:0.52292#011validation-error:0.53491
# [278]#011train-error:0.52248#011validation-error:0.53452
# [279]#011train-error:0.52189#011validation-error:0.53408
# [280]#011train-error:0.52184#011validation-error:0.53407
# [281]#011train-error:0.52141#011validation-error:0.53361
# [282]#011train-error:0.52081#011validation-error:0.53302
# [283]#011train-error:0.52075#011validation-error:0.53289
# [284]#011train-error:0.52065#011validation-error:0.53284
# [285]#011train-error:0.52054#011validation-error:0.53274
# [286]#011train-error:0.52031#011validation-error:0.53252
# [287]#011train-error:0.52016#011validation-error:0.53238
# [288]#011train-error:0.52002#011validation-error:0.53233
# [289]#011train-error:0.51997#011validation-error:0.53229
# [290]#011train-error:0.51994#011validation-error:0.53230
# [291]#011train-error:0.51988#011validation-error:0.53229
# [292]#011train-error:0.51952#011validation-error:0.53187
# [293]#011train-error:0.51894#011validation-error:0.53132
# [294]#011train-error:0.51879#011validation-error:0.53119
# [295]#011train-error:0.51822#011validation-error:0.53070
# [296]#011train-error:0.51796#011validation-error:0.53044
# [297]#011train-error:0.51776#011validation-error:0.53038
# [298]#011train-error:0.51766#011validation-error:0.53025
# [299]#011train-error:0.51750#011validation-error:0.53002
# [300]#011train-error:0.51743#011validation-error:0.52994
# [301]#011train-error:0.51722#011validation-error:0.52983
# [302]#011train-error:0.51644#011validation-error:0.52893
# [303]#011train-error:0.51629#011validation-error:0.52877
# [304]#011train-error:0.51610#011validation-error:0.52870
# [305]#011train-error:0.51571#011validation-error:0.52828
# [306]#011train-error:0.51564#011validation-error:0.52820
# [307]#011train-error:0.51516#011validation-error:0.52775
# [308]#011train-error:0.51466#011validation-error:0.52744
# [309]#011train-error:0.51464#011validation-error:0.52739
# [310]#011train-error:0.51433#011validation-error:0.52695
# [311]#011train-error:0.51390#011validation-error:0.52638
# [312]#011train-error:0.51382#011validation-error:0.52632
# [313]#011train-error:0.51336#011validation-error:0.52597
# [314]#011train-error:0.51330#011validation-error:0.52597
# [315]#011train-error:0.51317#011validation-error:0.52590
# [316]#011train-error:0.51298#011validation-error:0.52569
# [317]#011train-error:0.51292#011validation-error:0.52568
# [318]#011train-error:0.51266#011validation-error:0.52559
# [319]#011train-error:0.51230#011validation-error:0.52533
# [320]#011train-error:0.51220#011validation-error:0.52539
# [321]#011train-error:0.51198#011validation-error:0.52525
# [322]#011train-error:0.51186#011validation-error:0.52511
# [323]#011train-error:0.51168#011validation-error:0.52502
# [324]#011train-error:0.51154#011validation-error:0.52498
# [325]#011train-error:0.51085#011validation-error:0.52422
# [326]#011train-error:0.51066#011validation-error:0.52396
# [327]#011train-error:0.51052#011validation-error:0.52386
# [328]#011train-error:0.51039#011validation-error:0.52372
# [329]#011train-error:0.51004#011validation-error:0.52329
# [330]#011train-error:0.50992#011validation-error:0.52319
# [331]#011train-error:0.50958#011validation-error:0.52291
# [332]#011train-error:0.50904#011validation-error:0.52250
# [333]#011train-error:0.50884#011validation-error:0.52235
# [334]#011train-error:0.50878#011validation-error:0.52232
# [335]#011train-error:0.50869#011validation-error:0.52214
# [336]#011train-error:0.50855#011validation-error:0.52201
# [337]#011train-error:0.50830#011validation-error:0.52181
# [338]#011train-error:0.50774#011validation-error:0.52124
# [339]#011train-error:0.50742#011validation-error:0.52085
# [340]#011train-error:0.50692#011validation-error:0.52053
# [341]#011train-error:0.50686#011validation-error:0.52044
# [342]#011train-error:0.50677#011validation-error:0.52037
# [343]#011train-error:0.50675#011validation-error:0.52026
# [344]#011train-error:0.50637#011validation-error:0.51999
# [345]#011train-error:0.50605#011validation-error:0.51973
# [346]#011train-error:0.50600#011validation-error:0.51965
# [347]#011train-error:0.50576#011validation-error:0.51956
# [348]#011train-error:0.50550#011validation-error:0.51936
# [349]#011train-error:0.50526#011validation-error:0.51915
# [350]#011train-error:0.50511#011validation-error:0.51900
# [351]#011train-error:0.50497#011validation-error:0.51886
# [352]#011train-error:0.50470#011validation-error:0.51859
# [353]#011train-error:0.50462#011validation-error:0.51844
# [354]#011train-error:0.50448#011validation-error:0.51826
# [355]#011train-error:0.50442#011validation-error:0.51815
# [356]#011train-error:0.50434#011validation-error:0.51811
# [357]#011train-error:0.50435#011validation-error:0.51804
# [358]#011train-error:0.50401#011validation-error:0.51775
# [359]#011train-error:0.50386#011validation-error:0.51758
# [360]#011train-error:0.50366#011validation-error:0.51741
# [361]#011train-error:0.50354#011validation-error:0.51729
# [362]#011train-error:0.50326#011validation-error:0.51710
# [363]#011train-error:0.50313#011validation-error:0.51698
# [364]#011train-error:0.50282#011validation-error:0.51665
# [365]#011train-error:0.50250#011validation-error:0.51645
# [366]#011train-error:0.50227#011validation-error:0.51632
# [367]#011train-error:0.50214#011validation-error:0.51616
# [368]#011train-error:0.50205#011validation-error:0.51608
# [369]#011train-error:0.50201#011validation-error:0.51598
# [370]#011train-error:0.50159#011validation-error:0.51556
# [371]#011train-error:0.50140#011validation-error:0.51544
# [372]#011train-error:0.50126#011validation-error:0.51536
# [373]#011train-error:0.50107#011validation-error:0.51528
# [374]#011train-error:0.50088#011validation-error:0.51500
# [375]#011train-error:0.50079#011validation-error:0.51495
# [376]#011train-error:0.50073#011validation-error:0.51491
# [377]#011train-error:0.50034#011validation-error:0.51448
# [378]#011train-error:0.49990#011validation-error:0.51411
# [379]#011train-error:0.49984#011validation-error:0.51407
# [380]#011train-error:0.49963#011validation-error:0.51376
# [381]#011train-error:0.49953#011validation-error:0.51361
# [382]#011train-error:0.49942#011validation-error:0.51357
# [383]#011train-error:0.49882#011validation-error:0.51298
# [384]#011train-error:0.49864#011validation-error:0.51289
# [385]#011train-error:0.49835#011validation-error:0.51268
# [386]#011train-error:0.49794#011validation-error:0.51237
# [387]#011train-error:0.49789#011validation-error:0.51238
# [388]#011train-error:0.49777#011validation-error:0.51224
# [389]#011train-error:0.49755#011validation-error:0.51203
# [390]#011train-error:0.49750#011validation-error:0.51200
# [391]#011train-error:0.49733#011validation-error:0.51183
# [392]#011train-error:0.49717#011validation-error:0.51168
# [393]#011train-error:0.49712#011validation-error:0.51168
# [394]#011train-error:0.49709#011validation-error:0.51168
# [395]#011train-error:0.49696#011validation-error:0.51166
# [396]#011train-error:0.49672#011validation-error:0.51145
# [397]#011train-error:0.49630#011validation-error:0.51111
# [398]#011train-error:0.49620#011validation-error:0.51085
# [399]#011train-error:0.49578#011validation-error:0.51060
# [400]#011train-error:0.49566#011validation-error:0.51053
# [401]#011train-error:0.49534#011validation-error:0.51042
# [402]#011train-error:0.49530#011validation-error:0.51035
# [403]#011train-error:0.49521#011validation-error:0.51032
# [404]#011train-error:0.49490#011validation-error:0.51011
# [405]#011train-error:0.49484#011validation-error:0.51008
# [406]#011train-error:0.49470#011validation-error:0.50994
# [407]#011train-error:0.49460#011validation-error:0.50986
# [408]#011train-error:0.49435#011validation-error:0.50955
# [409]#011train-error:0.49416#011validation-error:0.50932
# [410]#011train-error:0.49408#011validation-error:0.50919
# [411]#011train-error:0.49400#011validation-error:0.50916
# [412]#011train-error:0.49390#011validation-error:0.50907
# [413]#011train-error:0.49380#011validation-error:0.50907
# [414]#011train-error:0.49368#011validation-error:0.50893
# [415]#011train-error:0.49348#011validation-error:0.50871
# [416]#011train-error:0.49338#011validation-error:0.50867
# [417]#011train-error:0.49321#011validation-error:0.50849
# [418]#011train-error:0.49306#011validation-error:0.50838
# [419]#011train-error:0.49276#011validation-error:0.50806
# [420]#011train-error:0.49233#011validation-error:0.50767
# [421]#011train-error:0.49198#011validation-error:0.50744
# [422]#011train-error:0.49183#011validation-error:0.50721
# [423]#011train-error:0.49171#011validation-error:0.50716
# [424]#011train-error:0.49167#011validation-error:0.50714
# [425]#011train-error:0.49156#011validation-error:0.50709
# [426]#011train-error:0.49150#011validation-error:0.50703
# [427]#011train-error:0.49144#011validation-error:0.50700
# [428]#011train-error:0.49136#011validation-error:0.50693
# [429]#011train-error:0.49122#011validation-error:0.50683
# [430]#011train-error:0.49108#011validation-error:0.50674
# [431]#011train-error:0.49096#011validation-error:0.50665
# [432]#011train-error:0.49091#011validation-error:0.50661
# [433]#011train-error:0.49068#011validation-error:0.50643
# [434]#011train-error:0.49039#011validation-error:0.50609
# [435]#011train-error:0.49025#011validation-error:0.50602
# [436]#011train-error:0.49007#011validation-error:0.50572
# [437]#011train-error:0.48979#011validation-error:0.50558
# [438]#011train-error:0.48969#011validation-error:0.50554
# [439]#011train-error:0.48956#011validation-error:0.50547
# [440]#011train-error:0.48916#011validation-error:0.50508
# [441]#011train-error:0.48887#011validation-error:0.50490
# [442]#011train-error:0.48881#011validation-error:0.50486
# [443]#011train-error:0.48874#011validation-error:0.50479
# [444]#011train-error:0.48864#011validation-error:0.50476
# [445]#011train-error:0.48848#011validation-error:0.50465
# [446]#011train-error:0.48822#011validation-error:0.50441
# [447]#011train-error:0.48799#011validation-error:0.50426
# [448]#011train-error:0.48764#011validation-error:0.50396
# [449]#011train-error:0.48726#011validation-error:0.50363
# [450]#011train-error:0.48718#011validation-error:0.50355
# [451]#011train-error:0.48702#011validation-error:0.50338
# [452]#011train-error:0.48667#011validation-error:0.50305
# [453]#011train-error:0.48665#011validation-error:0.50302
# [454]#011train-error:0.48652#011validation-error:0.50292
# [455]#011train-error:0.48647#011validation-error:0.50284
# [456]#011train-error:0.48642#011validation-error:0.50278
# [457]#011train-error:0.48638#011validation-error:0.50274
# [458]#011train-error:0.48602#011validation-error:0.50238
# [459]#011train-error:0.48578#011validation-error:0.50214
# [460]#011train-error:0.48574#011validation-error:0.50202
# [461]#011train-error:0.48571#011validation-error:0.50198
# [462]#011train-error:0.48566#011validation-error:0.50193
# [463]#011train-error:0.48555#011validation-error:0.50181
# [464]#011train-error:0.48530#011validation-error:0.50165
# [465]#011train-error:0.48500#011validation-error:0.50147
# [466]#011train-error:0.48490#011validation-error:0.50131
# [467]#011train-error:0.48468#011validation-error:0.50109
# [468]#011train-error:0.48462#011validation-error:0.50102
# [469]#011train-error:0.48442#011validation-error:0.50069
# [470]#011train-error:0.48423#011validation-error:0.50054
# [471]#011train-error:0.48404#011validation-error:0.50044
# [472]#011train-error:0.48402#011validation-error:0.50038
# [473]#011train-error:0.48372#011validation-error:0.50007
# [474]#011train-error:0.48362#011validation-error:0.49998
# [475]#011train-error:0.48326#011validation-error:0.49963
# [476]#011train-error:0.48310#011validation-error:0.49949
# [477]#011train-error:0.48269#011validation-error:0.49909
# [478]#011train-error:0.48234#011validation-error:0.49882
# [479]#011train-error:0.48205#011validation-error:0.49859
# [480]#011train-error:0.48190#011validation-error:0.49842
# [481]#011train-error:0.48172#011validation-error:0.49825
# [482]#011train-error:0.48152#011validation-error:0.49805
# [483]#011train-error:0.48135#011validation-error:0.49795
# [484]#011train-error:0.48092#011validation-error:0.49754
# [485]#011train-error:0.48076#011validation-error:0.49745
# [486]#011train-error:0.48072#011validation-error:0.49733
# [487]#011train-error:0.48068#011validation-error:0.49721
# [488]#011train-error:0.48049#011validation-error:0.49717
# [489]#011train-error:0.48014#011validation-error:0.49691
# [490]#011train-error:0.48002#011validation-error:0.49685
# [491]#011train-error:0.47988#011validation-error:0.49675
# [492]#011train-error:0.47963#011validation-error:0.49654
# [493]#011train-error:0.47953#011validation-error:0.49646
# [494]#011train-error:0.47949#011validation-error:0.49643
# [495]#011train-error:0.47941#011validation-error:0.49639
# [496]#011train-error:0.47932#011validation-error:0.49633
# [497]#011train-error:0.47924#011validation-error:0.49627
# [498]#011train-error:0.47917#011validation-error:0.49617
# [499]#011train-error:0.47906#011validation-error:0.49603
# [500]#011train-error:0.47878#011validation-error:0.49583
# [501]#011train-error:0.47851#011validation-error:0.49561
# [502]#011train-error:0.47845#011validation-error:0.49553
# [503]#011train-error:0.47830#011validation-error:0.49540
# [504]#011train-error:0.47810#011validation-error:0.49530
# [505]#011train-error:0.47807#011validation-error:0.49527
# [506]#011train-error:0.47802#011validation-error:0.49517
# [507]#011train-error:0.47783#011validation-error:0.49502
# [508]#011train-error:0.47777#011validation-error:0.49499
# [509]#011train-error:0.47761#011validation-error:0.49480
# [510]#011train-error:0.47758#011validation-error:0.49476
# [511]#011train-error:0.47754#011validation-error:0.49473
# [512]#011train-error:0.47728#011validation-error:0.49457
# [513]#011train-error:0.47722#011validation-error:0.49454
# [514]#011train-error:0.47718#011validation-error:0.49452
# [515]#011train-error:0.47704#011validation-error:0.49451
# [516]#011train-error:0.47698#011validation-error:0.49452
# [517]#011train-error:0.47693#011validation-error:0.49451
# [518]#011train-error:0.47673#011validation-error:0.49431
# [519]#011train-error:0.47652#011validation-error:0.49425
# [520]#011train-error:0.47641#011validation-error:0.49416
# [521]#011train-error:0.47638#011validation-error:0.49412
# [522]#011train-error:0.47628#011validation-error:0.49406
# [523]#011train-error:0.47612#011validation-error:0.49379
# [524]#011train-error:0.47602#011validation-error:0.49375
# [525]#011train-error:0.47569#011validation-error:0.49340
# [526]#011train-error:0.47558#011validation-error:0.49332
# [527]#011train-error:0.47539#011validation-error:0.49319
# [528]#011train-error:0.47525#011validation-error:0.49305
# [529]#011train-error:0.47517#011validation-error:0.49299
# [530]#011train-error:0.47513#011validation-error:0.49296
# [531]#011train-error:0.47494#011validation-error:0.49276
# [532]#011train-error:0.47483#011validation-error:0.49266
# [533]#011train-error:0.47467#011validation-error:0.49252
# [534]#011train-error:0.47464#011validation-error:0.49250
# [535]#011train-error:0.47446#011validation-error:0.49231
# [536]#011train-error:0.47422#011validation-error:0.49218
# [537]#011train-error:0.47416#011validation-error:0.49212
# [538]#011train-error:0.47410#011validation-error:0.49201
# [539]#011train-error:0.47398#011validation-error:0.49201
# [540]#011train-error:0.47383#011validation-error:0.49187
# [541]#011train-error:0.47372#011validation-error:0.49179
# [542]#011train-error:0.47362#011validation-error:0.49163
# [543]#011train-error:0.47354#011validation-error:0.49162
# [544]#011train-error:0.47351#011validation-error:0.49161
# [545]#011train-error:0.47342#011validation-error:0.49150
# [546]#011train-error:0.47317#011validation-error:0.49125
# [547]#011train-error:0.47286#011validation-error:0.49095
# [548]#011train-error:0.47281#011validation-error:0.49085
# [549]#011train-error:0.47277#011validation-error:0.49082
# [550]#011train-error:0.47264#011validation-error:0.49073
# [551]#011train-error:0.47234#011validation-error:0.49046
# [552]#011train-error:0.47213#011validation-error:0.49026
# [553]#011train-error:0.47198#011validation-error:0.49006
# [554]#011train-error:0.47186#011validation-error:0.48993
# [555]#011train-error:0.47144#011validation-error:0.48958
# [556]#011train-error:0.47118#011validation-error:0.48934
# [557]#011train-error:0.47106#011validation-error:0.48922
# [558]#011train-error:0.47091#011validation-error:0.48914
# [559]#011train-error:0.47058#011validation-error:0.48892
# [560]#011train-error:0.47053#011validation-error:0.48890
# [561]#011train-error:0.47051#011validation-error:0.48886
# [562]#011train-error:0.47032#011validation-error:0.48866
# [563]#011train-error:0.47020#011validation-error:0.48861
# [564]#011train-error:0.46990#011validation-error:0.48839
# [565]#011train-error:0.46963#011validation-error:0.48811
# [566]#011train-error:0.46953#011validation-error:0.48809
# [567]#011train-error:0.46949#011validation-error:0.48802
# [568]#011train-error:0.46939#011validation-error:0.48796
# [569]#011train-error:0.46934#011validation-error:0.48790
# [570]#011train-error:0.46929#011validation-error:0.48785
# [571]#011train-error:0.46926#011validation-error:0.48778
# [572]#011train-error:0.46908#011validation-error:0.48757
# [573]#011train-error:0.46880#011validation-error:0.48733
# [574]#011train-error:0.46866#011validation-error:0.48722
# [575]#011train-error:0.46844#011validation-error:0.48713
# [576]#011train-error:0.46831#011validation-error:0.48707
# [577]#011train-error:0.46812#011validation-error:0.48691
# [578]#011train-error:0.46794#011validation-error:0.48674
# [579]#011train-error:0.46770#011validation-error:0.48655
# [580]#011train-error:0.46761#011validation-error:0.48649
# [581]#011train-error:0.46755#011validation-error:0.48647
# [582]#011train-error:0.46740#011validation-error:0.48632
# [583]#011train-error:0.46727#011validation-error:0.48615
# [584]#011train-error:0.46713#011validation-error:0.48606
# [585]#011train-error:0.46655#011validation-error:0.48562
# [586]#011train-error:0.46625#011validation-error:0.48542
# [587]#011train-error:0.46616#011validation-error:0.48521
# [588]#011train-error:0.46610#011validation-error:0.48519
# [589]#011train-error:0.46600#011validation-error:0.48516
# [590]#011train-error:0.46592#011validation-error:0.48513
# [591]#011train-error:0.46586#011validation-error:0.48513
# [592]#011train-error:0.46586#011validation-error:0.48512
# [593]#011train-error:0.46581#011validation-error:0.48511
# [594]#011train-error:0.46568#011validation-error:0.48498
# [595]#011train-error:0.46546#011validation-error:0.48479
# [596]#011train-error:0.46530#011validation-error:0.48464
# [597]#011train-error:0.46494#011validation-error:0.48430
# [598]#011train-error:0.46461#011validation-error:0.48392
# [599]#011train-error:0.46434#011validation-error:0.48365
# [600]#011train-error:0.46424#011validation-error:0.48356
# [601]#011train-error:0.46423#011validation-error:0.48355
# [602]#011train-error:0.46405#011validation-error:0.48342
# [603]#011train-error:0.46373#011validation-error:0.48314
# [604]#011train-error:0.46356#011validation-error:0.48304
# [605]#011train-error:0.46350#011validation-error:0.48300
# [606]#011train-error:0.46348#011validation-error:0.48298
# [607]#011train-error:0.46341#011validation-error:0.48290
# [608]#011train-error:0.46339#011validation-error:0.48286
# [609]#011train-error:0.46331#011validation-error:0.48279
# [610]#011train-error:0.46320#011validation-error:0.48267
# [611]#011train-error:0.46303#011validation-error:0.48256
# [612]#011train-error:0.46287#011validation-error:0.48243
# [613]#011train-error:0.46275#011validation-error:0.48229
# [614]#011train-error:0.46273#011validation-error:0.48228
# [615]#011train-error:0.46266#011validation-error:0.48223
# [616]#011train-error:0.46250#011validation-error:0.48207
# [617]#011train-error:0.46234#011validation-error:0.48201
# [618]#011train-error:0.46226#011validation-error:0.48190
# [619]#011train-error:0.46193#011validation-error:0.48143
# [620]#011train-error:0.46170#011validation-error:0.48121
# [621]#011train-error:0.46154#011validation-error:0.48101
# [622]#011train-error:0.46143#011validation-error:0.48081
# [623]#011train-error:0.46120#011validation-error:0.48066
# [624]#011train-error:0.46108#011validation-error:0.48057
# [625]#011train-error:0.46091#011validation-error:0.48049
# [626]#011train-error:0.46090#011validation-error:0.48048
# [627]#011train-error:0.46049#011validation-error:0.48021
# [628]#011train-error:0.46029#011validation-error:0.48005
# [629]#011train-error:0.46019#011validation-error:0.48000
# [630]#011train-error:0.46006#011validation-error:0.47991
# [631]#011train-error:0.46000#011validation-error:0.47986
# [632]#011train-error:0.45994#011validation-error:0.47978
# [633]#011train-error:0.45990#011validation-error:0.47972
# [634]#011train-error:0.45977#011validation-error:0.47968
# [635]#011train-error:0.45965#011validation-error:0.47953
# [636]#011train-error:0.45950#011validation-error:0.47935
# [637]#011train-error:0.45938#011validation-error:0.47930
# [638]#011train-error:0.45932#011validation-error:0.47920
# [639]#011train-error:0.45924#011validation-error:0.47914
# [640]#011train-error:0.45916#011validation-error:0.47905
# [641]#011train-error:0.45882#011validation-error:0.47869
# [642]#011train-error:0.45853#011validation-error:0.47847
# [643]#011train-error:0.45836#011validation-error:0.47843
# [644]#011train-error:0.45832#011validation-error:0.47839
# [645]#011train-error:0.45824#011validation-error:0.47828
# [646]#011train-error:0.45802#011validation-error:0.47807
# [647]#011train-error:0.45758#011validation-error:0.47780
# [648]#011train-error:0.45725#011validation-error:0.47742
# [649]#011train-error:0.45689#011validation-error:0.47716
# [650]#011train-error:0.45674#011validation-error:0.47708
# [651]#011train-error:0.45662#011validation-error:0.47696
# [652]#011train-error:0.45661#011validation-error:0.47696
# [653]#011train-error:0.45656#011validation-error:0.47685
# [654]#011train-error:0.45648#011validation-error:0.47674
# [655]#011train-error:0.45633#011validation-error:0.47654
# [656]#011train-error:0.45627#011validation-error:0.47652
# [657]#011train-error:0.45604#011validation-error:0.47641
# [658]#011train-error:0.45602#011validation-error:0.47636
# [659]#011train-error:0.45597#011validation-error:0.47629
# [660]#011train-error:0.45588#011validation-error:0.47620
# [661]#011train-error:0.45561#011validation-error:0.47591
# [662]#011train-error:0.45540#011validation-error:0.47581
# [663]#011train-error:0.45533#011validation-error:0.47566
# [664]#011train-error:0.45524#011validation-error:0.47552
# [665]#011train-error:0.45518#011validation-error:0.47547
# [666]#011train-error:0.45484#011validation-error:0.47524
# [667]#011train-error:0.45479#011validation-error:0.47520
# [668]#011train-error:0.45471#011validation-error:0.47511
# [669]#011train-error:0.45458#011validation-error:0.47502
# [670]#011train-error:0.45445#011validation-error:0.47494
# [671]#011train-error:0.45437#011validation-error:0.47490
# [672]#011train-error:0.45416#011validation-error:0.47472
# [673]#011train-error:0.45410#011validation-error:0.47468
# [674]#011train-error:0.45402#011validation-error:0.47458
# [675]#011train-error:0.45389#011validation-error:0.47438
# [676]#011train-error:0.45380#011validation-error:0.47431
# [677]#011train-error:0.45366#011validation-error:0.47416
# [678]#011train-error:0.45361#011validation-error:0.47411
# [679]#011train-error:0.45344#011validation-error:0.47387
# [680]#011train-error:0.45329#011validation-error:0.47379
# [681]#011train-error:0.45324#011validation-error:0.47380
# [682]#011train-error:0.45323#011validation-error:0.47375
# [683]#011train-error:0.45318#011validation-error:0.47373
# [684]#011train-error:0.45312#011validation-error:0.47371
# [685]#011train-error:0.45308#011validation-error:0.47364
# [686]#011train-error:0.45292#011validation-error:0.47355
# [687]#011train-error:0.45279#011validation-error:0.47343
# [688]#011train-error:0.45245#011validation-error:0.47322
# [689]#011train-error:0.45222#011validation-error:0.47309
# [690]#011train-error:0.45210#011validation-error:0.47297
# [691]#011train-error:0.45199#011validation-error:0.47283
# [692]#011train-error:0.45192#011validation-error:0.47266
# [693]#011train-error:0.45176#011validation-error:0.47253
# [694]#011train-error:0.45116#011validation-error:0.47189
# [695]#011train-error:0.45077#011validation-error:0.47156
# [696]#011train-error:0.45068#011validation-error:0.47151
# [697]#011train-error:0.45054#011validation-error:0.47136
# [698]#011train-error:0.45038#011validation-error:0.47124
# [699]#011train-error:0.45035#011validation-error:0.47125
# [700]#011train-error:0.45028#011validation-error:0.47120
# [701]#011train-error:0.45008#011validation-error:0.47098
# [702]#011train-error:0.44996#011validation-error:0.47084
# [703]#011train-error:0.44984#011validation-error:0.47079
# [704]#011train-error:0.44971#011validation-error:0.47061
# [705]#011train-error:0.44967#011validation-error:0.47059
# [706]#011train-error:0.44966#011validation-error:0.47054
# [707]#011train-error:0.44952#011validation-error:0.47052
# [708]#011train-error:0.44950#011validation-error:0.47053
# [709]#011train-error:0.44946#011validation-error:0.47052
# [710]#011train-error:0.44940#011validation-error:0.47050
# [711]#011train-error:0.44937#011validation-error:0.47047
# [712]#011train-error:0.44935#011validation-error:0.47042
# [713]#011train-error:0.44928#011validation-error:0.47038
# [714]#011train-error:0.44922#011validation-error:0.47031
# [715]#011train-error:0.44917#011validation-error:0.47026
# [716]#011train-error:0.44920#011validation-error:0.47025
# [717]#011train-error:0.44872#011validation-error:0.47000
# [718]#011train-error:0.44862#011validation-error:0.46990
# [719]#011train-error:0.44832#011validation-error:0.46967
# [720]#011train-error:0.44808#011validation-error:0.46945
# [721]#011train-error:0.44805#011validation-error:0.46941
# [722]#011train-error:0.44793#011validation-error:0.46932
# [723]#011train-error:0.44762#011validation-error:0.46902
# [724]#011train-error:0.44750#011validation-error:0.46893
# [725]#011train-error:0.44745#011validation-error:0.46887
# [726]#011train-error:0.44723#011validation-error:0.46873
# [727]#011train-error:0.44703#011validation-error:0.46857
# [728]#011train-error:0.44699#011validation-error:0.46855
# [729]#011train-error:0.44693#011validation-error:0.46853
# [730]#011train-error:0.44684#011validation-error:0.46842
# [731]#011train-error:0.44652#011validation-error:0.46821
# [732]#011train-error:0.44642#011validation-error:0.46817
# [733]#011train-error:0.44635#011validation-error:0.46811
# [734]#011train-error:0.44624#011validation-error:0.46808
# [735]#011train-error:0.44622#011validation-error:0.46805
# [736]#011train-error:0.44618#011validation-error:0.46800
# [737]#011train-error:0.44606#011validation-error:0.46789
# [738]#011train-error:0.44587#011validation-error:0.46770
# [739]#011train-error:0.44580#011validation-error:0.46757
# [740]#011train-error:0.44570#011validation-error:0.46744
# [741]#011train-error:0.44547#011validation-error:0.46726
# [742]#011train-error:0.44545#011validation-error:0.46716
# [743]#011train-error:0.44528#011validation-error:0.46705
# [744]#011train-error:0.44514#011validation-error:0.46698
# [745]#011train-error:0.44506#011validation-error:0.46697
# [746]#011train-error:0.44502#011validation-error:0.46698
# [747]#011train-error:0.44476#011validation-error:0.46686
# [748]#011train-error:0.44459#011validation-error:0.46672
# [749]#011train-error:0.44455#011validation-error:0.46656
# [750]#011train-error:0.44436#011validation-error:0.46637
# [751]#011train-error:0.44427#011validation-error:0.46632
# [752]#011train-error:0.44420#011validation-error:0.46630
# [753]#011train-error:0.44415#011validation-error:0.46629
# [754]#011train-error:0.44407#011validation-error:0.46625
# [755]#011train-error:0.44395#011validation-error:0.46628
# [756]#011train-error:0.44393#011validation-error:0.46625
# [757]#011train-error:0.44380#011validation-error:0.46610
# [758]#011train-error:0.44368#011validation-error:0.46596
# [759]#011train-error:0.44357#011validation-error:0.46593
# [760]#011train-error:0.44339#011validation-error:0.46585
# [761]#011train-error:0.44320#011validation-error:0.46576
# [762]#011train-error:0.44302#011validation-error:0.46541
# [763]#011train-error:0.44286#011validation-error:0.46523
# [764]#011train-error:0.44258#011validation-error:0.46501
# [765]#011train-error:0.44250#011validation-error:0.46493
# [766]#011train-error:0.44239#011validation-error:0.46481
# [767]#011train-error:0.44220#011validation-error:0.46469
# [768]#011train-error:0.44197#011validation-error:0.46447
# [769]#011train-error:0.44192#011validation-error:0.46441
# [770]#011train-error:0.44176#011validation-error:0.46426
# [771]#011train-error:0.44160#011validation-error:0.46415
# [772]#011train-error:0.44156#011validation-error:0.46414
# [773]#011train-error:0.44154#011validation-error:0.46411
# [774]#011train-error:0.44149#011validation-error:0.46407
# [775]#011train-error:0.44144#011validation-error:0.46400
# [776]#011train-error:0.44136#011validation-error:0.46394
# [777]#011train-error:0.44122#011validation-error:0.46382
# [778]#011train-error:0.44088#011validation-error:0.46348
# [779]#011train-error:0.44072#011validation-error:0.46337
# [780]#011train-error:0.44048#011validation-error:0.46312
# [781]#011train-error:0.44022#011validation-error:0.46294
# [782]#011train-error:0.44002#011validation-error:0.46267
# [783]#011train-error:0.43985#011validation-error:0.46259
# [784]#011train-error:0.43985#011validation-error:0.46257
# [785]#011train-error:0.43981#011validation-error:0.46255
# [786]#011train-error:0.43957#011validation-error:0.46249
# [787]#011train-error:0.43945#011validation-error:0.46243
# [788]#011train-error:0.43934#011validation-error:0.46227
# [789]#011train-error:0.43899#011validation-error:0.46189
# [790]#011train-error:0.43880#011validation-error:0.46177
# [791]#011train-error:0.43879#011validation-error:0.46173
# [792]#011train-error:0.43867#011validation-error:0.46162
# [793]#011train-error:0.43859#011validation-error:0.46157
# [794]#011train-error:0.43856#011validation-error:0.46158
# [795]#011train-error:0.43850#011validation-error:0.46153
# [796]#011train-error:0.43846#011validation-error:0.46151
# [797]#011train-error:0.43840#011validation-error:0.46147
# [798]#011train-error:0.43820#011validation-error:0.46132
# [799]#011train-error:0.43798#011validation-error:0.46114
# [800]#011train-error:0.43786#011validation-error:0.46097
# [801]#011train-error:0.43785#011validation-error:0.46094
# [802]#011train-error:0.43781#011validation-error:0.46091
# [803]#011train-error:0.43765#011validation-error:0.46076
# [804]#011train-error:0.43746#011validation-error:0.46059
# [805]#011train-error:0.43719#011validation-error:0.46040
# [806]#011train-error:0.43707#011validation-error:0.46023
# ...
# [2728]#011train-error:0.29777#011validation-error:0.35719
# [2729]#011train-error:0.29774#011validation-error:0.35715
# [2730]#011train-error:0.29773#011validation-error:0.35713
# [2731]#011train-error:0.29773#011validation-error:0.35712
# [2732]#011train-error:0.29771#011validation-error:0.35712
# [2733]#011train-error:0.29768#011validation-error:0.35711
# [2734]#011train-error:0.29760#011validation-error:0.35708
# [2735]#011train-error:0.29757#011validation-error:0.35705
# [2736]#011train-error:0.29754#011validation-error:0.35706
# [2737]#011train-error:0.29752#011validation-error:0.35701
# [2738]#011train-error:0.29748#011validation-error:0.35699
# [2739]#011train-error:0.29747#011validation-error:0.35700
# [2740]#011train-error:0.29743#011validation-error:0.35695
# [2741]#011train-error:0.29740#011validation-error:0.35695
# [2742]#011train-error:0.29737#011validation-error:0.35692
# [2743]#011train-error:0.29737#011validation-error:0.35691
# [2744]#011train-error:0.29734#011validation-error:0.35696
# [2745]#011train-error:0.29731#011validation-error:0.35696
# [2746]#011train-error:0.29724#011validation-error:0.35684
# [2747]#011train-error:0.29710#011validation-error:0.35679
# [2748]#011train-error:0.29706#011validation-error:0.35680
# [2749]#011train-error:0.29702#011validation-error:0.35676
# [2750]#011train-error:0.29696#011validation-error:0.35673
# [2751]#011train-error:0.29688#011validation-error:0.35666
# [2752]#011train-error:0.29678#011validation-error:0.35655
# [2753]#011train-error:0.29675#011validation-error:0.35657
# [2754]#011train-error:0.29670#011validation-error:0.35651
# [2755]#011train-error:0.29666#011validation-error:0.35651
# [2756]#011train-error:0.29652#011validation-error:0.35637
# [2757]#011train-error:0.29644#011validation-error:0.35630
# [2758]#011train-error:0.29642#011validation-error:0.35635
# [2759]#011train-error:0.29636#011validation-error:0.35634
# [2760]#011train-error:0.29620#011validation-error:0.35620
# [2761]#011train-error:0.29620#011validation-error:0.35621
# [2762]#011train-error:0.29613#011validation-error:0.35617
# [2763]#011train-error:0.29608#011validation-error:0.35621
# [2764]#011train-error:0.29606#011validation-error:0.35620
# [2765]#011train-error:0.29604#011validation-error:0.35622
# [2766]#011train-error:0.29604#011validation-error:0.35620
# [2767]#011train-error:0.29587#011validation-error:0.35603
# [2768]#011train-error:0.29577#011validation-error:0.35591
# [2769]#011train-error:0.29572#011validation-error:0.35590
# [2770]#011train-error:0.29567#011validation-error:0.35580
# [2771]#011train-error:0.29561#011validation-error:0.35584
# [2772]#011train-error:0.29547#011validation-error:0.35569
# [2773]#011train-error:0.29544#011validation-error:0.35569
# [2774]#011train-error:0.29536#011validation-error:0.35562
# [2775]#011train-error:0.29533#011validation-error:0.35562
# [2776]#011train-error:0.29529#011validation-error:0.35557
# [2777]#011train-error:0.29526#011validation-error:0.35554
# [2778]#011train-error:0.29521#011validation-error:0.35556
# [2779]#011train-error:0.29517#011validation-error:0.35554
# [2780]#011train-error:0.29517#011validation-error:0.35552
# [2781]#011train-error:0.29512#011validation-error:0.35550
# [2782]#011train-error:0.29509#011validation-error:0.35552
# [2783]#011train-error:0.29498#011validation-error:0.35545
# [2784]#011train-error:0.29491#011validation-error:0.35542
# [2785]#011train-error:0.29490#011validation-error:0.35541
# [2786]#011train-error:0.29488#011validation-error:0.35540
# [2787]#011train-error:0.29485#011validation-error:0.35536
# [2788]#011train-error:0.29472#011validation-error:0.35524
# [2789]#011train-error:0.29474#011validation-error:0.35523
# [2790]#011train-error:0.29468#011validation-error:0.35518
# [2791]#011train-error:0.29463#011validation-error:0.35516
# [2792]#011train-error:0.29463#011validation-error:0.35516
# [2793]#011train-error:0.29460#011validation-error:0.35513
# [2794]#011train-error:0.29458#011validation-error:0.35511
# [2795]#011train-error:0.29455#011validation-error:0.35510
# [2796]#011train-error:0.29451#011validation-error:0.35508
# [2797]#011train-error:0.29451#011validation-error:0.35508
# [2798]#011train-error:0.29440#011validation-error:0.35505
# [2799]#011train-error:0.29439#011validation-error:0.35505
# [2800]#011train-error:0.29436#011validation-error:0.35506
# [2801]#011train-error:0.29432#011validation-error:0.35508
# [2802]#011train-error:0.29430#011validation-error:0.35506
# [2803]#011train-error:0.29424#011validation-error:0.35500
# [2804]#011train-error:0.29424#011validation-error:0.35499
# [2805]#011train-error:0.29418#011validation-error:0.35491
# [2806]#011train-error:0.29413#011validation-error:0.35492
# [2807]#011train-error:0.29407#011validation-error:0.35487
# [2808]#011train-error:0.29392#011validation-error:0.35480
# [2809]#011train-error:0.29390#011validation-error:0.35483
# [2810]#011train-error:0.29380#011validation-error:0.35476
# [2811]#011train-error:0.29376#011validation-error:0.35475
# [2812]#011train-error:0.29372#011validation-error:0.35476
# [2813]#011train-error:0.29368#011validation-error:0.35473
# [2814]#011train-error:0.29366#011validation-error:0.35475
# [2815]#011train-error:0.29359#011validation-error:0.35475
# [2816]#011train-error:0.29350#011validation-error:0.35465
# [2817]#011train-error:0.29344#011validation-error:0.35462
# [2818]#011train-error:0.29342#011validation-error:0.35462
# [2819]#011train-error:0.29335#011validation-error:0.35456
# [2820]#011train-error:0.29334#011validation-error:0.35449
# [2821]#011train-error:0.29332#011validation-error:0.35450
# [2822]#011train-error:0.29329#011validation-error:0.35447
# [2823]#011train-error:0.29324#011validation-error:0.35444
# [2824]#011train-error:0.29320#011validation-error:0.35441
# [2825]#011train-error:0.29312#011validation-error:0.35438
# [2826]#011train-error:0.29310#011validation-error:0.35435
# [2827]#011train-error:0.29311#011validation-error:0.35436
# [2828]#011train-error:0.29304#011validation-error:0.35430
# [2829]#011train-error:0.29301#011validation-error:0.35430
# [2830]#011train-error:0.29298#011validation-error:0.35431
# [2831]#011train-error:0.29293#011validation-error:0.35430
# [2832]#011train-error:0.29286#011validation-error:0.35425
# [2833]#011train-error:0.29284#011validation-error:0.35422
# [2834]#011train-error:0.29279#011validation-error:0.35419
# [2835]#011train-error:0.29272#011validation-error:0.35419
# [2836]#011train-error:0.29270#011validation-error:0.35418
# [2837]#011train-error:0.29270#011validation-error:0.35420
# [2838]#011train-error:0.29266#011validation-error:0.35418
# [2839]#011train-error:0.29264#011validation-error:0.35422
# [2840]#011train-error:0.29258#011validation-error:0.35404
# [2841]#011train-error:0.29242#011validation-error:0.35398
# [2842]#011train-error:0.29234#011validation-error:0.35392
# [2843]#011train-error:0.29228#011validation-error:0.35379
# [2844]#011train-error:0.29222#011validation-error:0.35381
# [2845]#011train-error:0.29217#011validation-error:0.35373
# [2846]#011train-error:0.29205#011validation-error:0.35370
# [2847]#011train-error:0.29204#011validation-error:0.35368
# [2848]#011train-error:0.29200#011validation-error:0.35366
# [2849]#011train-error:0.29195#011validation-error:0.35362
# [2850]#011train-error:0.29192#011validation-error:0.35357
# [2851]#011train-error:0.29181#011validation-error:0.35348
# [2852]#011train-error:0.29178#011validation-error:0.35349
# [2853]#011train-error:0.29176#011validation-error:0.35346
# [2854]#011train-error:0.29172#011validation-error:0.35347
# [2855]#011train-error:0.29166#011validation-error:0.35338
# [2856]#011train-error:0.29163#011validation-error:0.35333
# [2857]#011train-error:0.29160#011validation-error:0.35333
# [2858]#011train-error:0.29149#011validation-error:0.35329
# [2859]#011train-error:0.29146#011validation-error:0.35330
# [2860]#011train-error:0.29141#011validation-error:0.35327
# [2861]#011train-error:0.29139#011validation-error:0.35323
# [2862]#011train-error:0.29137#011validation-error:0.35324
# [2863]#011train-error:0.29134#011validation-error:0.35318
# [2864]#011train-error:0.29130#011validation-error:0.35316
# [2865]#011train-error:0.29128#011validation-error:0.35318
# [2866]#011train-error:0.29123#011validation-error:0.35321
# [2867]#011train-error:0.29123#011validation-error:0.35321
# [2868]#011train-error:0.29122#011validation-error:0.35320
# [2869]#011train-error:0.29115#011validation-error:0.35318
# [2870]#011train-error:0.29113#011validation-error:0.35316
# [2871]#011train-error:0.29110#011validation-error:0.35315
# [2872]#011train-error:0.29108#011validation-error:0.35315
# [2873]#011train-error:0.29104#011validation-error:0.35314
# [2874]#011train-error:0.29099#011validation-error:0.35315
# [2875]#011train-error:0.29097#011validation-error:0.35315
# [2876]#011train-error:0.29090#011validation-error:0.35311
# [2877]#011train-error:0.29086#011validation-error:0.35306
# [2878]#011train-error:0.29080#011validation-error:0.35306
# [2879]#011train-error:0.29064#011validation-error:0.35293
# [2880]#011train-error:0.29061#011validation-error:0.35286
# [2881]#011train-error:0.29058#011validation-error:0.35284
# [2882]#011train-error:0.29058#011validation-error:0.35284
# [2883]#011train-error:0.29056#011validation-error:0.35285
# [2884]#011train-error:0.29051#011validation-error:0.35272
# [2885]#011train-error:0.29051#011validation-error:0.35268
# [2886]#011train-error:0.29045#011validation-error:0.35262
# [2887]#011train-error:0.29043#011validation-error:0.35267
# [2888]#011train-error:0.29042#011validation-error:0.35266
# [2889]#011train-error:0.29038#011validation-error:0.35265
# [2890]#011train-error:0.29036#011validation-error:0.35261
# [2891]#011train-error:0.29033#011validation-error:0.35258
# [2892]#011train-error:0.29022#011validation-error:0.35258
# [2893]#011train-error:0.29017#011validation-error:0.35248
# [2894]#011train-error:0.29013#011validation-error:0.35244
# [2895]#011train-error:0.29008#011validation-error:0.35238
# [2896]#011train-error:0.29004#011validation-error:0.35235
# [2897]#011train-error:0.29003#011validation-error:0.35234
# [2898]#011train-error:0.29000#011validation-error:0.35234
# [2899]#011train-error:0.28998#011validation-error:0.35233
# [2900]#011train-error:0.28996#011validation-error:0.35233
# [2901]#011train-error:0.28987#011validation-error:0.35232
# [2902]#011train-error:0.28985#011validation-error:0.35233
# [2903]#011train-error:0.28984#011validation-error:0.35233
# [2904]#011train-error:0.28978#011validation-error:0.35235
# [2905]#011train-error:0.28969#011validation-error:0.35238
# [2906]#011train-error:0.28966#011validation-error:0.35237
# [2907]#011train-error:0.28959#011validation-error:0.35226
# [2908]#011train-error:0.28957#011validation-error:0.35226
# [2909]#011train-error:0.28956#011validation-error:0.35227
# [2910]#011train-error:0.28947#011validation-error:0.35216
# [2911]#011train-error:0.28938#011validation-error:0.35212
# [2912]#011train-error:0.28926#011validation-error:0.35208
# [2913]#011train-error:0.28917#011validation-error:0.35209
# [2914]#011train-error:0.28911#011validation-error:0.35203
# [2915]#011train-error:0.28910#011validation-error:0.35203
# [2916]#011train-error:0.28908#011validation-error:0.35197
# [2917]#011train-error:0.28898#011validation-error:0.35190
# [2918]#011train-error:0.28897#011validation-error:0.35182
# [2919]#011train-error:0.28894#011validation-error:0.35180
# [2920]#011train-error:0.28892#011validation-error:0.35179
# [2921]#011train-error:0.28890#011validation-error:0.35179
# [2922]#011train-error:0.28887#011validation-error:0.35177
# [2923]#011train-error:0.28881#011validation-error:0.35175
# [2924]#011train-error:0.28877#011validation-error:0.35170
# [2925]#011train-error:0.28876#011validation-error:0.35174
# [2926]#011train-error:0.28874#011validation-error:0.35164
# [2927]#011train-error:0.28870#011validation-error:0.35161
# [2928]#011train-error:0.28860#011validation-error:0.35150
# [2929]#011train-error:0.28851#011validation-error:0.35151
# [2930]#011train-error:0.28851#011validation-error:0.35148
# [2931]#011train-error:0.28844#011validation-error:0.35146
# [2932]#011train-error:0.28840#011validation-error:0.35145
# [2933]#011train-error:0.28840#011validation-error:0.35143
# [2934]#011train-error:0.28835#011validation-error:0.35137
# [2935]#011train-error:0.28834#011validation-error:0.35133
# [2936]#011train-error:0.28827#011validation-error:0.35132
# [2937]#011train-error:0.28825#011validation-error:0.35132
# [2938]#011train-error:0.28823#011validation-error:0.35133
# [2939]#011train-error:0.28822#011validation-error:0.35128
# [2940]#011train-error:0.28818#011validation-error:0.35129
# [2941]#011train-error:0.28817#011validation-error:0.35130
# [2942]#011train-error:0.28810#011validation-error:0.35129
# [2943]#011train-error:0.28801#011validation-error:0.35121
# [2944]#011train-error:0.28798#011validation-error:0.35115
# [2945]#011train-error:0.28791#011validation-error:0.35113
# [2946]#011train-error:0.28784#011validation-error:0.35109
# [2947]#011train-error:0.28776#011validation-error:0.35106
# [2948]#011train-error:0.28773#011validation-error:0.35104
# [2949]#011train-error:0.28765#011validation-error:0.35099
# [2950]#011train-error:0.28753#011validation-error:0.35086
# [2951]#011train-error:0.28744#011validation-error:0.35087
# [2952]#011train-error:0.28744#011validation-error:0.35085
# [2953]#011train-error:0.28736#011validation-error:0.35074
# [2954]#011train-error:0.28729#011validation-error:0.35068
# [2955]#011train-error:0.28722#011validation-error:0.35064
# [2956]#011train-error:0.28718#011validation-error:0.35056
# [2957]#011train-error:0.28698#011validation-error:0.35045
# [2958]#011train-error:0.28682#011validation-error:0.35029
# [2959]#011train-error:0.28672#011validation-error:0.35022
# [2960]#011train-error:0.28657#011validation-error:0.35020
# [2961]#011train-error:0.28652#011validation-error:0.35020
# [2962]#011train-error:0.28651#011validation-error:0.35024
# [2963]#011train-error:0.28652#011validation-error:0.35022
# [2964]#011train-error:0.28648#011validation-error:0.35015
# [2965]#011train-error:0.28643#011validation-error:0.35018
# [2966]#011train-error:0.28641#011validation-error:0.35008
# [2967]#011train-error:0.28632#011validation-error:0.35007
# [2968]#011train-error:0.28634#011validation-error:0.35004
# [2969]#011train-error:0.28631#011validation-error:0.35004
# [2970]#011train-error:0.28627#011validation-error:0.35002
# [2971]#011train-error:0.28622#011validation-error:0.34997
# [2972]#011train-error:0.28614#011validation-error:0.34998
# [2973]#011train-error:0.28602#011validation-error:0.34990
# [2974]#011train-error:0.28593#011validation-error:0.34981
# [2975]#011train-error:0.28582#011validation-error:0.34976
# [2976]#011train-error:0.28578#011validation-error:0.34974
# [2977]#011train-error:0.28580#011validation-error:0.34967
# [2978]#011train-error:0.28574#011validation-error:0.34961
# [2979]#011train-error:0.28565#011validation-error:0.34963
# [2980]#011train-error:0.28559#011validation-error:0.34959
# [2981]#011train-error:0.28550#011validation-error:0.34963
# [2982]#011train-error:0.28538#011validation-error:0.34956
# [2983]#011train-error:0.28534#011validation-error:0.34954
# [2984]#011train-error:0.28525#011validation-error:0.34943
# [2985]#011train-error:0.28519#011validation-error:0.34927
# [2986]#011train-error:0.28509#011validation-error:0.34920
# [2987]#011train-error:0.28508#011validation-error:0.34917
# [2988]#011train-error:0.28499#011validation-error:0.34911
# [2989]#011train-error:0.28489#011validation-error:0.34892
# [2990]#011train-error:0.28484#011validation-error:0.34886
# [2991]#011train-error:0.28479#011validation-error:0.34882
# [2992]#011train-error:0.28477#011validation-error:0.34880
# [2993]#011train-error:0.28474#011validation-error:0.34875
# [2994]#011train-error:0.28472#011validation-error:0.34872
# [2995]#011train-error:0.28466#011validation-error:0.34869
# [2996]#011train-error:0.28462#011validation-error:0.34864
# [2997]#011train-error:0.28458#011validation-error:0.34861
# [2998]#011train-error:0.28452#011validation-error:0.34859
# [2999]#011train-error:0.28453#011validation-error:0.34857
#
# 2021-01-11 17:36:20 Uploading - Uploading generated training model
# 2021-01-11 17:36:20 Completed - Training job completed
# Training seconds: 3556
# Billable seconds: 3556

# %%
import os
#get name of profiler report
profiler_report_name = [rule["RuleConfigurationName"] 
                        for rule in estimator.latest_training_job.rule_job_summary() 
                        if "Profiler" in rule["RuleConfigurationName"]][0]

xgb_profile_job_name = [rule["RuleEvaluationJobArn"].split("/")[-1] 
                        for rule in estimator.latest_training_job.rule_job_summary() 
                        if "CreateXgboostReport" in rule["RuleConfigurationName"]][0]

base_output_path = os.path.dirname(estimator.latest_job_debugger_artifacts_path())
rule_output_path = os.path.join(base_output_path, "rule-output/")
xgb_report_path = os.path.join(rule_output_path, "CreateXgboostReport")
profile_report_path = os.path.join(rule_output_path, profiler_report_name)

# %%
while True:
    
    xgb_job_info = sess.sagemaker_client.describe_processing_job(ProcessingJobName=xgb_profile_job_name)

    if xgb_job_info["ProcessingJobStatus"] == "Completed":
        break
    else:
        print(f"Job Status: {xgb_job_info['ProcessingJobStatus']}")
        time.sleep(30)

s3.download(xgb_report_path, "reports/xgb/", recursive=True)
s3.download(profile_report_path, "reports/profiler/", recursive=True)
display(HTML("""<h3>Training Profiling Jobs Finished!</h3>
            <h4>
            <a href='/view/XGBoost%20Viz%20Blog/reports/profiler/profiler-output/profiler-report.html'> 
            Click here to view the Profiler Report
            </a>
            </h4>
            <h4>
            <a href='/view/XGBoost%20Viz%20Blog/reports/xgb/xgboost_report.html'> 
            Click here to view the XGBoost Training Report
            </a>
            </h4>"""))
# Out:
# Job Status: InProgress
# Job Status: InProgress
# Job Status: InProgress
# Job Status: InProgress
# Job Status: InProgress
# Job Status: InProgress
# Job Status: InProgress
# <h3>Training Profiling Jobs Finished!</h3>
#             <h4>
#             <a href='/view/XGBoost%20Viz%20Blog/reports/profiler/profiler-output/profiler-report.html'>
#             Click here to view the Profiler Report
#             </a>
#             </h4>
#             <h4>
#             <a href='/view/XGBoost%20Viz%20Blog/reports/xgb/xgboost_report.html'>
#             Click here to view the XGBoost Training Report
#             </a>
#             </h4>

# %%
updated_hyperparameters={
    "eta": "0.1",
    "max_depth": "6",
    "objective": "binary:logistic",
    "num_round": "50"
}

# %%
improved_estimator=Estimator(
    role=role,
    image_uri=xgboost_container,
    base_job_name="higgs-boson-model",
    instance_count=1,
    instance_type="ml.m5.xlarge",
    hyperparameters=updated_hyperparameters,
    rules=rules
)

improved_estimator.fit({'train': train_input, 'validation': validation_input}, wait=True)

# %%
improved_estimator.latest_training_job.job_name
